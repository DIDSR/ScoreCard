# %%
import os
import sys

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils import consistency_analysis

# %%
real_meta_csv                   = '../data/real_patch_appearance_with_metadata.csv'
synth_meta_csv                  = '../data/kde_patch_appearance_with_metadata.csv'

cons_df_race, cons_fig_race     = consistency_analysis(real_meta_csv, synth_meta_csv, group_by="Race", label="report")
cons_fig_race.show()
# Out:
#   Variance_of_Group_Means  : 89.076266
#   Max_Min_Difference       : 21.750000
#   ANOVA_F_statistic        : 1.9519
#   ANOVA_p_value            : 0.06406
#   Variance_of_Group_Means  : 101.644861
#   Max_Min_Difference       : 23.800000
#   ANOVA_F_statistic        : 2.0767
#   ANOVA_p_value            : 0.04824
#   Variance_of_Group_Means  : 119.238355
#   Max_Min_Difference       : 25.550000
#   ANOVA_F_statistic        : 1.6958
#   ANOVA_p_value            : 0.1631
#   Variance_of_Group_Means  : 125.726527
#   Max_Min_Difference       : 26.790000
#   ANOVA_F_statistic        : 1.6546
#   ANOVA_p_value            : 0.1727
#   Variance_of_Group_Means  : 72.851991
#   Max_Min_Difference       : 26.242000
#   ANOVA_F_statistic        : 1.8703
#   ANOVA_p_value            : 0.0776
#   Variance_of_Group_Means  : 70.730297
#   Max_Min_Difference       : 25.718000
#   ANOVA_F_statistic        : 1.8349
#   ANOVA_p_value            : 0.08388
#   Variance_of_Group_Means  : 0.005778
# ...

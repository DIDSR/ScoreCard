# %%
import os
import sys

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils import hist_analysis

# %%
histo_fig, metrics_data = hist_analysis('../data/features')

histo_fig.show()

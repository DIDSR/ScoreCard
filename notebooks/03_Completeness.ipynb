# %%
import os
import sys

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils import completeness_analysis

# %%
real_meta_csv     = '../data/real_patch_appearance_with_metadata.csv'
synth_meta_csv    = '../data/kde_patch_appearance_with_metadata.csv'

comp_df, comp_fig = completeness_analysis(real_meta_csv, synth_meta_csv, label="report")
comp_fig.show()
# Out:
#   Missing_Data_Percentage       : 30.37%
#   Required_Fields_Completeness  : 69.63%
#   Missing_Data_Percentage       : 72.70%
#   Required_Fields_Completeness  : 27.30%
# /home/alexander.webber/programming/ScoreCard/src/visualization.py:481: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /home/alexander.webber/programming/ScoreCard/src/visualization.py:481: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import os
import sys

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.analyses import hist_analysis

# %%
features_to_plot = {
    'mean_intensity'  : True,
    'glcm_contrast'   : True,
    'glcm_correlation': True,
    'glcm_energy'     : True,
    'mean_r'          : True,
    'mean_g'          : True,
    'mean_b'          : True,
}

feature_names = [name for name, enabled in features_to_plot.items() if enabled]

# %%
histo_fig, metrics_data = hist_analysis(
    '../data/features',
    feature_names=feature_names,
)

histo_fig.show()
